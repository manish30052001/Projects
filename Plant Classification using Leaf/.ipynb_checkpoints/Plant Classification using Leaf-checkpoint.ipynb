# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./Augumented Data/Species_Data_2.csv')

# %%
df
# Out:
#       Unnamed: 0    ID                Species
# 0              0     1            Acer_Opalus
# 1              1     2  Pterocarya_Stenoptera
# 2              2     3   Quercus_Hartwissiana
# 3              3     4        Tilia_Tomentosa
# 4              4     5     Quercus_Variabilis
# ...          ...   ...                    ...
# 3955        3955  3956   Magnolia_Salicifolia
# 3956        3956  3957            Acer_Pictum
# 3957        3957  3958     Alnus_Maximowiczii
# 3958        3958  3959          Quercus_Rubra
# 3959        3959  3960         Quercus_Afares
#
# [3960 rows x 3 columns]

# %%
df.drop("Unnamed: 0", inplace = True, axis = 1)

# %%
df
# Out:
#         ID                Species
# 0        1            Acer_Opalus
# 1        2  Pterocarya_Stenoptera
# 2        3   Quercus_Hartwissiana
# 3        4        Tilia_Tomentosa
# 4        5     Quercus_Variabilis
# ...    ...                    ...
# 3955  3956   Magnolia_Salicifolia
# 3956  3957            Acer_Pictum
# 3957  3958     Alnus_Maximowiczii
# 3958  3959          Quercus_Rubra
# 3959  3960         Quercus_Afares
#
# [3960 rows x 2 columns]

# %%
df['ID'] = df['ID'].astype(str) + ".jpg"

# %%
df
# Out:
#             ID                Species
# 0        1.jpg            Acer_Opalus
# 1        2.jpg  Pterocarya_Stenoptera
# 2        3.jpg   Quercus_Hartwissiana
# 3        4.jpg        Tilia_Tomentosa
# 4        5.jpg     Quercus_Variabilis
# ...        ...                    ...
# 3955  3956.jpg   Magnolia_Salicifolia
# 3956  3957.jpg            Acer_Pictum
# 3957  3958.jpg     Alnus_Maximowiczii
# 3958  3959.jpg          Quercus_Rubra
# 3959  3960.jpg         Quercus_Afares
#
# [3960 rows x 2 columns]

# %%
df["Index"] = range(1, 3961)

# %%
df
# Out:
#             ID                Species  Index
# 0        1.jpg            Acer_Opalus      1
# 1        2.jpg  Pterocarya_Stenoptera      2
# 2        3.jpg   Quercus_Hartwissiana      3
# 3        4.jpg        Tilia_Tomentosa      4
# 4        5.jpg     Quercus_Variabilis      5
# ...        ...                    ...    ...
# 3955  3956.jpg   Magnolia_Salicifolia   3956
# 3956  3957.jpg            Acer_Pictum   3957
# 3957  3958.jpg     Alnus_Maximowiczii   3958
# 3958  3959.jpg          Quercus_Rubra   3959
# 3959  3960.jpg         Quercus_Afares   3960
#
# [3960 rows x 3 columns]

# %%
df.set_index('Index', inplace=True)

# %%
df
# Out:
#              ID                Species
# Index
# 1         1.jpg            Acer_Opalus
# 2         2.jpg  Pterocarya_Stenoptera
# 3         3.jpg   Quercus_Hartwissiana
# 4         4.jpg        Tilia_Tomentosa
# 5         5.jpg     Quercus_Variabilis
# ...         ...                    ...
# 3956   3956.jpg   Magnolia_Salicifolia
# 3957   3957.jpg            Acer_Pictum
# 3958   3958.jpg     Alnus_Maximowiczii
# 3959   3959.jpg          Quercus_Rubra
# 3960   3960.jpg         Quercus_Afares
#
# [3960 rows x 2 columns]

# %%
y_train = df.sample(frac=0.8)

# %%
y_train
# Out:
#              ID                Species
# Index
# 2677   2677.jpg            Alnus_Rubra
# 1497   1497.jpg      Quercus_Crassipes
# 985     985.jpg           Ilex_Cornuta
# 1501   1501.jpg  Quercus_Ellipsoidalis
# 3335   3335.jpg        Ilex_Aquifolium
# ...         ...                    ...
# 822     822.jpg            Acer_Opalus
# 3203   3203.jpg          Quercus_Rubra
# 268     268.jpg        Quercus_Trojana
# 2093   2093.jpg       Quercus_Kewensis
# 2818   2818.jpg    Eucalyptus_Urnigera
#
# [3168 rows x 2 columns]

# %%
df2 = df.drop(y_train.index)

# %%
df2
# Out:
#              ID                Species
# Index
# 2         2.jpg  Pterocarya_Stenoptera
# 6         6.jpg   Magnolia_Salicifolia
# 14       14.jpg         Quercus_Afares
# 15       15.jpg      Quercus_Coccifera
# 18       18.jpg          Acer_Palmatum
# ...         ...                    ...
# 3944   3944.jpg      Quercus_Vulcanica
# 3947   3947.jpg        Acer_Capillipes
# 3954   3954.jpg        Quercus_Phellos
# 3955   3955.jpg           Ilex_Cornuta
# 3960   3960.jpg         Quercus_Afares
#
# [792 rows x 2 columns]

# %%
y_test = df2.sample(frac=0.5)
y_test
# Out:
#              ID                      Species
# Index
# 2526   2526.jpg              Quercus_Greggii
# 548     548.jpg         Magnolia_Salicifolia
# 1024   1024.jpg  Rhododendron_x_Russellianum
# 1680   1680.jpg              Quercus_Phellos
# 1689   1689.jpg          Quercus_Rhysophylla
# ...         ...                          ...
# 2502   2502.jpg       Eucalyptus_Glaucescens
# 2550   2550.jpg  Rhododendron_x_Russellianum
# 3265   3265.jpg             Quercus_Kewensis
# 3180   3180.jpg                Quercus_Rubra
# 542     542.jpg                  Sorbus_Aria
#
# [396 rows x 2 columns]

# %%
y_valid = df2.drop(y_test.index)

# %%
y_valid
# Out:
#              ID                Species
# Index
# 6         6.jpg   Magnolia_Salicifolia
# 15       15.jpg      Quercus_Coccifera
# 18       18.jpg          Acer_Palmatum
# 50       50.jpg       Acer_Saccharinum
# 53       53.jpg        Quercus_Greggii
# ...         ...                    ...
# 3917   3917.jpg              Acer_Mono
# 3931   3931.jpg      Quercus_Vulcanica
# 3934   3934.jpg  Populus_Grandidentata
# 3944   3944.jpg      Quercus_Vulcanica
# 3947   3947.jpg        Acer_Capillipes
#
# [396 rows x 2 columns]

# %%
y_train['ID']
# Out:
# Index
# 2677    2677.jpg
# 1497    1497.jpg
# 985      985.jpg
# 1501    1501.jpg
# 3335    3335.jpg
#           ...
# 822      822.jpg
# 3203    3203.jpg
# 268      268.jpg
# 2093    2093.jpg
# 2818    2818.jpg
# Name: ID, Length: 3168, dtype: object

# %%
y_test['ID']
# Out:
# Index
# 2526    2526.jpg
# 548      548.jpg
# 1024    1024.jpg
# 1680    1680.jpg
# 1689    1689.jpg
#           ...
# 2502    2502.jpg
# 2550    2550.jpg
# 3265    3265.jpg
# 3180    3180.jpg
# 542      542.jpg
# Name: ID, Length: 396, dtype: object

# %%
y_valid['ID']
# Out:
# Index
# 6          6.jpg
# 15        15.jpg
# 18        18.jpg
# 50        50.jpg
# 53        53.jpg
#           ...
# 3917    3917.jpg
# 3931    3931.jpg
# 3934    3934.jpg
# 3944    3944.jpg
# 3947    3947.jpg
# Name: ID, Length: 396, dtype: object

# %%
y_train.Species.nunique()
# Out:
# 99

# %%
y_test.Species.nunique()
# Out:
# 99

# %%
y_valid.Species.nunique()
# Out:
# 98

# %%
y_test, y_valid = y_valid, y_test

# %%
y_valid.Species.nunique()
# Out:
# 99

# %%
y_train.to_csv("./Augumented Data/train.csv")

# %%
y_test.to_csv("./Augumented Data/test.csv")

# %%
y_valid.to_csv("./Augumented Data/valid.csv")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale=1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
image_shape = (256, 256,1)

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(99, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 254, 254, 32)      320
#
#  max_pooling2d_4 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 60, 60, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 128)               7372928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 99)                12771
#
# ...
# Total params: 7,441,443
# Trainable params: 7,441,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_generator = datagen.flow_from_dataframe(dataframe=y_train, directory='./Augumented Data/Data', x_col='ID', y_col="Species", color_mode="grayscale", class_mode="categorical", target_size=(256, 256), batch_size=16)
# Out:
# Found 3168 validated image filenames belonging to 99 classes.

# %%
valid_generator = datagen.flow_from_dataframe(dataframe=y_valid, directory='./Augumented Data/Data', x_col='ID', y_col="Species", color_mode="grayscale", class_mode="categorical", target_size=(256, 256), batch_size=16)
# Out:
# Found 396 validated image filenames belonging to 99 classes.

# %%
test_generator = datagen.flow_from_dataframe(dataframe=y_test, directory='./Augumented Data/Data', x_col='ID', y_col="Species", color_mode="grayscale", class_mode="categorical", target_size=(256, 256), batch_size=16)
# Out:
# Found 396 validated image filenames belonging to 98 classes.

# %%
step_size_train = train_generator.n//train_generator.batch_size

# %%
step_size_valid = valid_generator.n//valid_generator.batch_size

# %%
results = model.fit_generator(generator=train_generator, steps_per_epoch=step_size_train, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# Out:
# Epoch 1/10
# C:\Users\HP\AppData\Local\Temp/ipykernel_15908/838225141.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(generator=train_generator, steps_per_epoch=step_size_train, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# 198/198 [==============================] - 194s 983ms/step - loss: 0.0348 - accuracy: 0.9880
# Epoch 2/10
# 198/198 [==============================] - 202s 1s/step - loss: 0.0361 - accuracy: 0.9896
# Epoch 3/10
# 198/198 [==============================] - 210s 1s/step - loss: 0.0254 - accuracy: 0.9912
# Epoch 4/10
# 198/198 [==============================] - 207s 1s/step - loss: 0.0344 - accuracy: 0.9886
# Epoch 5/10
# 198/198 [==============================] - 205s 1s/step - loss: 0.0311 - accuracy: 0.9908
# Epoch 6/10
# ...

# %%
results.history
# Out:
# {'loss': [0.0347723625600338,
#   0.036132629960775375,
#   0.025415834039449692,
#   0.034421175718307495,
#   0.031082699075341225,
#   0.02246823161840439,
#   0.015954099595546722,
#   0.024039680138230324,
#   0.014680777676403522,
#   0.024997113272547722],
#  'accuracy': [0.9880050420761108,
#   0.9895833134651184,
#   0.9911616444587708,
#   0.9886363744735718,
#   0.9908459782600403,
#   0.9933711886405945,
#   0.993686854839325,
#   0.9940025210380554,
#   0.9946338534355164,
#   0.9933711886405945]}

# %%
losses[['accuracy', 'val_accuracy']].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15908/2901435114.py in <module>
# ----> 1 losses[['accuracy', 'val_accuracy']].plot()
#
# NameError: name 'losses' is not defined

# %%
model.save("./Augumented Data/my_model_1.h5")

# %%
results1 = model.fit_generator(generator=train_generator, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# Out:
# Epoch 1/10
# C:\Users\HP\AppData\Local\Temp/ipykernel_15908/1811987983.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results1 = model.fit_generator(generator=train_generator, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# ...
# 198/198 [==============================] - 184s 932ms/step - loss: 0.0132 - accuracy: 0.9972 - val_loss: 1.1037 - val_accuracy: 0.8384
# Epoch 2/10
#   4/198 [..............................] - ETA: 2:52 - loss: 0.0569 - accuracy: 0.9844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15908/1811987983.py in <module>
# ----> 1 results1 = model.fit_generator(generator=train_generator, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
#
# ...

# %%
results1.history
# Out:
# {'loss': [0.05487988516688347,
#   0.04127860441803932,
#   0.052588820457458496,
#   0.036913350224494934,
#   0.04134482517838478,
#   0.0376046746969223,
#   0.04070417955517769,
#   0.029173314571380615,
#   0.05117018148303032,
#   0.025645826011896133],
#  'accuracy': [0.9826388955116272,
#   0.9854797720909119,
#   0.9848484992980957,
#   0.9886363744735718,
#   0.9873737096786499,
#   0.9895833134651184,
#   0.9880050420761108,
#   0.9917929172515869,
#   0.9870581030845642,
#   0.9914772510528564]}

# %%
results1.history['accuracy']
# Out:
# [0.9826388955116272,
#  0.9854797720909119,
#  0.9848484992980957,
#  0.9886363744735718,
#  0.9873737096786499,
#  0.9895833134651184,
#  0.9880050420761108,
#  0.9917929172515869,
#  0.9870581030845642,
#  0.9914772510528564]

# %%
results1.history['loss']
# Out:
# [0.05487988516688347,
#  0.04127860441803932,
#  0.052588820457458496,
#  0.036913350224494934,
#  0.04134482517838478,
#  0.0376046746969223,
#  0.04070417955517769,
#  0.029173314571380615,
#  0.05117018148303032,
#  0.025645826011896133]

# %%
results1.history['val_accuracy']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15908/139224267.py in <module>
# ----> 1 results1.history['val_accuracy']
#
# KeyError: 'val_accuracy'

# %%
results = model.fit_generator(generator=train_generator, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# Out:
# Epoch 1/10
# C:\Users\HP\AppData\Local\Temp/ipykernel_15908/3517229655.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(generator=train_generator, validation_data=valid_generator, validation_steps=step_size_valid, epochs=10)
# 198/198 [==============================] - 187s 946ms/step - loss: 0.0301 - accuracy: 0.9902 - val_loss: 1.1407 - val_accuracy: 0.8411
# Epoch 2/10
# 198/198 [==============================] - 202s 1s/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.9571 - val_accuracy: 0.8490
# Epoch 3/10
# 198/198 [==============================] - 177s 893ms/step - loss: 0.0174 - accuracy: 0.9940 - val_loss: 1.1810 - val_accuracy: 0.8438
# Epoch 4/10
# 198/198 [==============================] - 214s 1s/step - loss: 0.0159 - accuracy: 0.9943 - val_loss: 1.3584 - val_accuracy: 0.8594
# Epoch 5/10
# ...

# %%
results.history
# Out:
# {'loss': [0.03009767085313797,
#   0.03304167091846466,
#   0.017367061227560043,
#   0.01593572460114956,
#   0.02109650708734989,
#   0.023812534287571907,
#   0.017092665657401085,
#   0.013623685576021671,
#   0.0138908252120018,
#   0.01458599790930748],
#  'accuracy': [0.9902146458625793,
#   0.9902146458625793,
#   0.9940025210380554,
#   0.9943181872367859,
#   0.9921085834503174,
#   0.9933711886405945,
#   0.993686854839325,
#   0.9946338534355164,
#   0.995580792427063,
#   0.9952651262283325],
#  'val_loss': [1.1406594514846802,
#   0.9570679068565369,
#   1.181033968925476,
#   1.358446717262268,
#   1.391894817352295,
#   1.0237877368927002,
#   1.1398035287857056,
#   1.1370930671691895,
#   1.117780089378357,
#   1.082593560218811],
#  'val_accuracy': [0.8411458134651184,
#   0.8489583134651184,
#   0.84375,
#   0.859375,
#   0.8307291865348816,
#   0.8411458134651184,
#   0.84375,
#   0.8385416865348816,
#   0.8333333134651184,
#   0.8489583134651184]}

# %%
model.save("./Augumented Data/my_model_2.h5")

# %%
res = pd.DataFrame(results.history)

# %%
res
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.030098  0.990215  1.140659      0.841146
# 1  0.033042  0.990215  0.957068      0.848958
# 2  0.017367  0.994003  1.181034      0.843750
# 3  0.015936  0.994318  1.358447      0.859375
# 4  0.021097  0.992109  1.391895      0.830729
# 5  0.023813  0.993371  1.023788      0.841146
# 6  0.017093  0.993687  1.139804      0.843750
# 7  0.013624  0.994634  1.137093      0.838542
# 8  0.013891  0.995581  1.117780      0.833333
# 9  0.014586  0.995265  1.082594      0.848958

# %%
res[['accuracy', 'val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
res[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
label_map = train_generator.class_indices

# %%
label_map
# Out:
# {'Acer_Capillipes': 0,
#  'Acer_Circinatum': 1,
#  'Acer_Mono': 2,
#  'Acer_Opalus': 3,
#  'Acer_Palmatum': 4,
#  'Acer_Pictum': 5,
#  'Acer_Platanoids': 6,
#  'Acer_Rubrum': 7,
#  'Acer_Rufinerve': 8,
#  'Acer_Saccharinum': 9,
#  'Alnus_Cordata': 10,
#  'Alnus_Maximowiczii': 11,
#  'Alnus_Rubra': 12,
#  'Alnus_Sieboldiana': 13,
#  'Alnus_Viridis': 14,
#  'Arundinaria_Simonii': 15,
#  'Betula_Austrosinensis': 16,
#  'Betula_Pendula': 17,
#  'Callicarpa_Bodinieri': 18,
#  'Castanea_Sativa': 19,
#  'Celtis_Koraiensis': 20,
#  'Cercis_Siliquastrum': 21,
#  'Cornus_Chinensis': 22,
#  'Cornus_Controversa': 23,
#  'Cornus_Macrophylla': 24,
#  'Cotinus_Coggygria': 25,
#  'Crataegus_Monogyna': 26,
#  'Cytisus_Battandieri': 27,
#  'Eucalyptus_Glaucescens': 28,
#  'Eucalyptus_Neglecta': 29,
#  'Eucalyptus_Urnigera': 30,
#  'Fagus_Sylvatica': 31,
#  'Ginkgo_Biloba': 32,
#  'Ilex_Aquifolium': 33,
#  'Ilex_Cornuta': 34,
#  'Liquidambar_Styraciflua': 35,
#  'Liriodendron_Tulipifera': 36,
# ...

# %%
y_test
# Out:
#              ID                Species
# Index
# 6         6.jpg   Magnolia_Salicifolia
# 15       15.jpg      Quercus_Coccifera
# 18       18.jpg          Acer_Palmatum
# 50       50.jpg       Acer_Saccharinum
# 53       53.jpg        Quercus_Greggii
# ...         ...                    ...
# 3917   3917.jpg              Acer_Mono
# 3931   3931.jpg      Quercus_Vulcanica
# 3934   3934.jpg  Populus_Grandidentata
# 3944   3944.jpg      Quercus_Vulcanica
# 3947   3947.jpg        Acer_Capillipes
#
# [396 rows x 2 columns]

# %%
testing_data = pd.DataFrame(y_test.ID)

# %%
testing_data.reset_index(inplace=True)

# %%
testing_data
# Out:
#      Index        ID
# 0        6     6.jpg
# 1       15    15.jpg
# 2       18    18.jpg
# 3       50    50.jpg
# 4       53    53.jpg
# ..     ...       ...
# 391   3917  3917.jpg
# 392   3931  3931.jpg
# 393   3934  3934.jpg
# 394   3944  3944.jpg
# 395   3947  3947.jpg
#
# [396 rows x 2 columns]

# %%
testing_image = list(testing_data.ID)

# %%
testing_image
# Out:
# ['6.jpg',
#  '15.jpg',
#  '18.jpg',
#  '50.jpg',
#  '53.jpg',
#  '83.jpg',
#  '88.jpg',
#  '102.jpg',
#  '104.jpg',
#  '112.jpg',
#  '123.jpg',
#  '129.jpg',
#  '144.jpg',
#  '146.jpg',
#  '148.jpg',
#  '149.jpg',
#  '154.jpg',
#  '176.jpg',
#  '191.jpg',
#  '197.jpg',
#  '198.jpg',
#  '213.jpg',
#  '217.jpg',
#  '252.jpg',
#  '261.jpg',
#  '265.jpg',
#  '271.jpg',
#  '299.jpg',
#  '308.jpg',
#  '309.jpg',
#  '310.jpg',
#  '317.jpg',
#  '340.jpg',
#  '344.jpg',
#  '347.jpg',
#  '351.jpg',
#  '358.jpg',
#  '367.jpg',
#  '371.jpg',
#  '399.jpg',
#  '400.jpg',
#  '406.jpg',
#  '410.jpg',
#  '422.jpg',
#  '423.jpg',
#  '435.jpg',
#  '440.jpg',
#  '442.jpg',
#  '443.jpg',
#  '451.jpg',
#  '456.jpg',
#  '458.jpg',
#  '465.jpg',
#  '469.jpg',
#  '471.jpg',
#  '477.jpg',
#  '478.jpg',
#  '481.jpg',
#  '495.jpg',
#  '505.jpg',
#  '547.jpg',
#  '555.jpg',
#  '566.jpg',
#  '575.jpg',
#  '585.jpg',
#  '590.jpg',
#  '595.jpg',
#  '609.jpg',
#  '631.jpg',
#  '651.jpg',
#  '663.jpg',
#  '688.jpg',
# ...

# %%
from PIL import Image, ImageFilter
import tensorflow as tf
import keras.preprocessing
predictions = []

for filename in testing_image:
    img = Image.open('./Augumented Data/Data/' + filename)
    img = img.resize((256, 256))
    input_arr = keras.preprocessing.image.img_to_array(img)
    input_arr = np.array([input_arr])
    R = model.predict(input_arr)
    Pre_Species = pd.DataFrame({'Id': list(R.reshape(99)),'LabelMap': list(label_map)})
    predictions.append(str(Pre_Species[Pre_Species.Id==1.0].LabelMap).split()[1])

# %%
predictions
# Out:
# ['Lithocarpus_Cleistocarpus',
#  'Quercus_Coccifera',
#  'Acer_Saccharinum',
#  'Acer_Saccharinum',
#  'Quercus_Greggii',
#  'Prunus_Avium',
#  'Celtis_Koraiensis',
#  'Quercus_Canariensis',
#  'Alnus_Cordata',
#  'Acer_Capillipes',
#  'Crataegus_Monogyna',
#  'Ilex_Cornuta',
#  'Magnolia_Salicifolia',
#  'Magnolia_Salicifolia',
#  'Fagus_Sylvatica',
#  'Quercus_Trojana',
#  'Quercus_Ilex',
#  'Quercus_Crassipes',
#  'Quercus_Palustris',
#  'Zelkova_Serrata',
#  'Magnolia_Salicifolia',
#  'Cotinus_Coggygria',
#  'Acer_Saccharinum',
#  'Cytisus_Battandieri',
#  'Quercus_Pontica',
#  'Quercus_Texana',
#  'Olea_Europaea',
#  'Quercus_Trojana',
#  'Quercus_Crassipes',
#  'Alnus_Cordata',
#  'Acer_Saccharinum',
#  'Quercus_Agrifolia',
#  'Callicarpa_Bodinieri',
#  'Quercus_Shumardii',
#  'Liquidambar_Styraciflua',
#  'Cotinus_Coggygria',
#  'Acer_Platanoids',
#  'Quercus_Semecarpifolia',
#  'Acer_Capillipes',
#  'Quercus_Greggii',
#  'Populus_Adenopoda',
#  'Quercus_Infectoria_sub',
# ...

# %%
len(predictions)
# Out:
# 396

# %%
ImageId_Species_test = pd.DataFrame({'Id': [str(a) for a in testing_image] , 'Species': predictions})

# %%
ImageId_Species_test
# Out:
#            Id                    Species
# 0       6.jpg  Lithocarpus_Cleistocarpus
# 1      15.jpg          Quercus_Coccifera
# 2      18.jpg           Acer_Saccharinum
# 3      50.jpg           Acer_Saccharinum
# 4      53.jpg            Quercus_Greggii
# ..        ...                        ...
# 391  3917.jpg                  Acer_Mono
# 392  3931.jpg          Quercus_Vulcanica
# 393  3934.jpg      Populus_Grandidentata
# 394  3944.jpg          Quercus_Vulcanica
# 395  3947.jpg            Acer_Capillipes
#
# [396 rows x 2 columns]

# %%
predictions
# Out:
# ['Quercus_Greggii',
#  'Magnolia_Salicifolia',
#  'Lithocarpus_Edulis',
#  'Quercus_Phellos',
#  'Quercus_Rhysophylla',
#  'Acer_Opalus',
#  'Quercus_Cerris',
#  'Acer_Mono',
#  'Alnus_Cordata',
#  'Quercus_Cerris',
#  'Quercus_Brantii',
#  'Acer_Palmatum',
#  'Acer_Capillipes',
#  'Quercus_Suber',
#  'Eucalyptus_Neglecta',
#  'Acer_Palmatum',
#  'Quercus_Pubescens',
#  'Quercus_Suber',
#  'Cercis_Siliquastrum',
#  'Crataegus_Monogyna',
#  'Viburnum_Tinus',
#  'Ilex_Cornuta',
#  'Quercus_Infectoria_sub',
#  'Quercus_x_Hispanica',
#  'Populus_Grandidentata',
#  'Acer_Palmatum',
#  'Quercus_Pontica',
#  'Acer_Capillipes',
#  'Quercus_Crassipes',
#  'Quercus_Dolicholepis',
#  'Acer_Capillipes',
#  'Prunus_X_Shmittii',
#  'Quercus_Crassipes',
#  'Ginkgo_Biloba',
#  'Quercus_Brantii',
#  'Quercus_Suber',
#  'Prunus_Avium',
#  'Quercus_Phillyraeoides',
#  'Callicarpa_Bodinieri',
#  'Alnus_Sieboldiana',
#  'Quercus_Semecarpifolia',
#  'Tilia_Platyphyllos',
#  'Name:',
#  'Quercus_Phellos',
# ...

# %%
y_test.reset_index(inplace=True)

# %%
truth = list(y_test['Species'])

# %%
truth
# Out:
# ['Magnolia_Salicifolia',
#  'Quercus_Coccifera',
#  'Acer_Palmatum',
#  'Acer_Saccharinum',
#  'Quercus_Greggii',
#  'Prunus_Avium',
#  'Celtis_Koraiensis',
#  'Quercus_Canariensis',
#  'Alnus_Cordata',
#  'Acer_Capillipes',
#  'Crataegus_Monogyna',
#  'Ilex_Cornuta',
#  'Lithocarpus_Cleistocarpus',
#  'Magnolia_Salicifolia',
#  'Fagus_Sylvatica',
#  'Quercus_Trojana',
#  'Quercus_Ilex',
#  'Quercus_Crassipes',
#  'Quercus_Palustris',
#  'Zelkova_Serrata',
#  'Magnolia_Salicifolia',
#  'Cotinus_Coggygria',
#  'Acer_Saccharinum',
#  'Cytisus_Battandieri',
#  'Quercus_Pontica',
#  'Quercus_Texana',
#  'Olea_Europaea',
#  'Quercus_Trojana',
#  'Olea_Europaea',
#  'Alnus_Cordata',
#  'Acer_Saccharinum',
#  'Quercus_Agrifolia',
#  'Callicarpa_Bodinieri',
#  'Quercus_Shumardii',
#  'Liquidambar_Styraciflua',
#  'Cotinus_Coggygria',
#  'Acer_Platanoids',
#  'Quercus_Semecarpifolia',
#  'Acer_Capillipes',
#  'Quercus_Greggii',
#  'Populus_Adenopoda',
#  'Quercus_Infectoria_sub',
# ...

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix , classification_report
import pandas as pd
import seaborn as sns

# %%
# Source code credit for this function: https://gist.github.com/shaypal5/94c53d765083101efc0240d776a23823
def print_confusion_matrix(confusion_matrix, class_names, figsize = (40,40), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
species = list(df['Species'].unique())

# %%
species
# Out:
# ['Acer_Opalus',
#  'Pterocarya_Stenoptera',
#  'Quercus_Hartwissiana',
#  'Tilia_Tomentosa',
#  'Quercus_Variabilis',
#  'Magnolia_Salicifolia',
#  'Quercus_Canariensis',
#  'Quercus_Rubra',
#  'Quercus_Brantii',
#  'Salix_Fragilis',
#  'Zelkova_Serrata',
#  'Betula_Austrosinensis',
#  'Quercus_Pontica',
#  'Quercus_Afares',
#  'Quercus_Coccifera',
#  'Fagus_Sylvatica',
#  'Phildelphus',
#  'Acer_Palmatum',
#  'Quercus_Pubescens',
#  'Populus_Adenopoda',
#  'Quercus_Trojana',
#  'Alnus_Sieboldiana',
#  'Quercus_Ilex',
#  'Arundinaria_Simonii',
#  'Acer_Platanoids',
#  'Quercus_Phillyraeoides',
#  'Cornus_Chinensis',
#  'Liriodendron_Tulipifera',
#  'Cytisus_Battandieri',
#  'Rhododendron_x_Russellianum',
#  'Alnus_Rubra',
#  'Eucalyptus_Glaucescens',
#  'Cercis_Siliquastrum',
#  'Cotinus_Coggygria',
#  'Celtis_Koraiensis',
#  'Quercus_Crassifolia',
#  'Quercus_Kewensis',
#  'Cornus_Controversa',
#  'Quercus_Pyrenaica',
#  'Callicarpa_Bodinieri',
#  'Quercus_Alnifolia',
# ...

# %%
cm = confusion_matrix(truth,predictions)
print_confusion_matrix(cm,species)

# %%
type(truth)
# Out:
# list

# %%
type(predictions)
# Out:
# list

# %%
print(classification_report(truth, predictions))
# Out:
#                               precision    recall  f1-score   support
#
#              Acer_Capillipes       1.00      1.00      1.00         5
#              Acer_Circinatum       0.80      0.80      0.80         5
#                    Acer_Mono       1.00      1.00      1.00         5
#                  Acer_Opalus       1.00      1.00      1.00         3
#                Acer_Palmatum       0.50      0.67      0.57         3
#                  Acer_Pictum       1.00      1.00      1.00         1
#              Acer_Platanoids       1.00      0.75      0.86         4
#                  Acer_Rubrum       1.00      1.00      1.00         3
#               Acer_Rufinerve       1.00      1.00      1.00         8
#             Acer_Saccharinum       0.89      1.00      0.94         8
#                Alnus_Cordata       1.00      0.88      0.93         8
#           Alnus_Maximowiczii       0.83      0.83      0.83         6
# ...
